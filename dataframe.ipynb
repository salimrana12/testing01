# %%
import pandas as pd

# %%
city = ['bangladesh', 'singapur', 'astraliya']

# %%
df = pd.DataFrame(city, columns=['city in asia'], index=['c1', 'c2', 'c3'])

# %%
df
# Out:
#    city in asia
# c1   bangladesh
# c2     singapur
# c3    astraliya

# %%
type(city)
# Out:
# list

# %%
city2 = ['dhaka', 'sylet', 'chittagang']

# %%
df2 = pd.DataFrame(zip(city, city2), columns=['c1', 'c2'], index=['t1', 't2', 't3'])

# %%
df2
# Out:
#             c1          c2
# t1  bangladesh       dhaka
# t2    singapur       sylet
# t3   astraliya  chittagang
